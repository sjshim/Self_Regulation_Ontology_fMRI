# %% [markdown]
# ### Imports

# %%
import argparse
from inspect import currentframe, getframeinfo
from glob import glob
from pathlib import Path
from nipype.interfaces import fsl
from nipype.algorithms.modelgen import SpecifyModel
from nipype.interfaces.base import Bunch
from nipype.interfaces.utility import Function, IdentityInterface
from nipype.interfaces.io import SelectFiles, DataSink
from nipype.pipeline.engine import Workflow, Node
import os
from os.path import join
import pandas as pd
import pickle
import sys
from utils.event_utils import get_beta_series, get_contrasts, parse_EVs, process_confounds
# Out:
# 180816-15:50:50,38 duecredit ERROR:
# 	 Failed to import duecredit due to No module named 'duecredit'
# /usr/local/miniconda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/local/miniconda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# ### Parse Arguments
# These are not needed for the jupyter notebook, but are used after conversion to a script for production
#
# - conversion command:
#   - jupyter nbconvert --to script --execute 1stlevel_analysis.ipynb

# %%
parser = argparse.ArgumentParser(description='Example BIDS App entrypoint script.')
parser.add_argument('-data_dir', default='/data')
parser.add_argument('-derivatives_dir', default=None)
parser.add_argument('-working_dir', default=None)
parser.add_argument('--participant_label')
parser.add_argument('--tasks', nargs="+")
parser.add_argument('--skip_beta', action='store_false')
parser.add_argument('--skip_contrast', action='store_false')
parser.add_argument('--n_procs', default=16, type=int)
if '-derivatives_dir' in sys.argv or '-h' in sys.argv:
    args = parser.parse_args()
else:
    args = parser.parse_args([])
    args.data_dir = '/mnt/OAK'
    args.derivatives_dir = '/home/ian/tmp/fmri/derivatives/'
    args.tasks = ['stroop']
    args.participant_label = 's130'
    args.n_procs=4

# %% [markdown]
# ### Initial Setup

# %%
# get current directory to pass to function nodes
filename = getframeinfo(currentframe()).filename
current_directory = str(Path(filename).resolve().parent)

# list of subject identifiers
subject_id = args.participant_label
# list of task identifiers
if args.tasks is not None:
    task_list = args.tasks
else:
    task_list = ['ANT', 'CCTHot', 'discountFix',
               'DPX', 'motorSelectiveStop',
               'stopSignal', 'stroop', 'surveyMedley',
               'twoByTwo', 'WATT3']

#### Experiment Variables
derivatives_dir = args.derivatives_dir
fmriprep_dir = join(derivatives_dir, 'fmriprep', 'fmriprep')
data_dir = args.data_dir
first_level_dir = join(derivatives_dir,'1stlevel')
if args.working_dir is None:
    working_dir = join(derivatives_dir, '1stlevel_workingdir')
else:
    working_dir = join(args.working_dir, '1stlevel_workingdir')
run_beta = args.skip_beta
run_contrast = args.skip_contrast
n_procs = args.n_procs
# TR of functional images
TR = .68

# %%
# print
print('*'*79)
print('Task List: %s\n, Subject: %s\n, derivatives_dir: %s\n, data_dir: %s' % 
     (task_list, subject_id, derivatives_dir, data_dir))
print('Running Contrast?: %s, Running Beta?: %s' % 
     (['No','Yes'][run_contrast], ['No','Yes'][run_beta]))
print('*'*79)
# Out:
# *******************************************************************************
# Task List: ['stroop']
# , Subject: s130
# , derivatives_dir: /home/ian/tmp/fmri/derivatives/
# , data_dir: /mnt/OAK
# Running Contrast?: Yes, Running Beta?: Yes
# *******************************************************************************

# %% [markdown]
# # Set up Nodes

# %% [markdown]
# ### Define helper functions

# %%
def get_events_regressors(data_dir, fmirprep_dir, subject_id, task):
    # strip "sub" from beginning of subject_id if provided
    subject_id = subject_id.replace('sub-','')
    ## Get the Confounds File (output of fmriprep)
    # Read the TSV file and convert to pandas dataframe
    confounds_file = glob(join(fmriprep_dir,
                               'sub-%s' % subject_id,
                               '*', 'func',
                               '*%s*confounds.tsv' % task))[0]
    regressors, regressor_names = process_confounds(confounds_file)
    ## Get the Events File if it exists
    # Read the TSV file and convert to pandas dataframe
    event_file = glob(join(data_dir,
                           'sub-%s' % subject_id,
                           '*', 'func',
                           '*%s*events.tsv' % task))   
    if len(event_file)>0:
        # set up events file
        event_file = event_file[0]
        events_df = pd.read_csv(event_file,sep = '\t')
    else:
        events_df = None
    regressors, regressor_names = process_confounds(confounds_file)
    return events_df, regressors, regressor_names

# helper function to create bunch
def getsubjectinfo(events_dr, regressors, regressor_names, task='beta', regress_rt=True): 
    EV_dict = parse_EVs(events_df, task, regress_rt)
    contrasts = []
    if task not in ['beta']:
        contrasts = get_contrasts(task, regress_rt)
    # create beta series info
    subjectinfo = Bunch(conditions=EV_dict['conditions'],
                        onsets=EV_dict['onsets'],
                        durations=EV_dict['durations'],
                        amplitudes=EV_dict['amplitudes'],
                        tmod=None,
                        pmod=None,
                        regressor_names=regressor_names,
                        regressors=regressors.T.tolist(),
                        contrasts=contrasts)
    return subjectinfo
    
def save_subjectinfo(save_directory, subjectinfo):
    os.makedirs(save_directory, exist_ok=True)
    subjectinfo_path = join(save_directory, 'subjectinfo.pkl')
    pickle.dump(subjectinfo, open(subjectinfo_path,'wb'))

# %% [markdown]
# ### Specify Input and Output Stream

# %%
def get_selector(task, subject_id, session=None):
    if session is None:
        ses = '*'
    else:
        ses = 'ses-%s' % str(session)
    # SelectFiles - to grab the data (alternative to DataGrabber)
    templates = {'func': join('sub-{subject_id}',ses,'func',
                             '*{task}*MNI*preproc.nii.gz'),
                 'mask': join('sub-{subject_id}',ses,'func',
                              '*{task}*MNI*brainmask.nii.gz')}
    selectfiles = Node(SelectFiles(templates,
                                   base_directory=fmriprep_dir,
                                   sort_filelist=True),
                       name='%s_selectFiles' % task)
    selectfiles.inputs.task = task
    selectfiles.inputs.subject_id = subject_id
    return selectfiles

def get_masker(name):
    # mask and blur
    return Node(fsl.maths.ApplyMask(),name=name)

# %% [markdown]
# # Create workflow

# %% [markdown]
# ### helper functions

# %%
def init_common_wf(workflow, task):
    # initiate basic nodes
    masker = get_masker('%s_masker' % task)
    selectfiles = get_selector(task, subject_id)
    # Connect up the 1st-level analysis components
    workflow.connect([(selectfiles, masker, [('func','in_file'), ('mask', 'mask_file')])])

def init_GLM_wf(subject_info, task, wf_label='model-standard_wf-standard', derivs=True):
    name = '%s_%s' % (task, wf_label)
    # Datasink - creates output folder for important outputs
    datasink = Node(DataSink(base_directory=first_level_dir,
                             container=subject_id), name="datasink")
    # Use the following DataSink output substitutions
    substitutions = [('_subject_id_', ''),
                    ('fstat', 'FSTST'),
                    ('run0.mat', 'designfile.mat')]
    
    datasink.inputs.substitutions = substitutions
    # ridiculous regexp substitution to get files just right
    # link to ridiculousness: https://regex101.com/r/ljS5zK/3
    match_str = "(?P<sub>s[0-9]+)\/(?P<task>[A-Za-z1-9_]+)_(?P<model>model-[a-z]+)_(?P<submodel>wf-[a-z]+)\/(s[0-9]+/|)"
    replace_str = "\g<sub>/\g<task>/\g<model>/\g<submodel>/"
    regexp_substitutions = [(match_str, replace_str)]
    datasink.inputs.regexp_substitutions = regexp_substitutions
    
    # SpecifyModel - Generates FSL-specific Model
    modelspec = Node(SpecifyModel(input_units='secs',
                                  time_repetition=TR,
                                  high_pass_filter_cutoff=80),
                     name="%s_modelspec" % task)
    modelspec.inputs.subject_info = subject_info
    # Level1Design - Creates FSL config file 
    level1design = Node(fsl.Level1Design(bases={'dgamma':{'derivs': derivs}},
                                         interscan_interval=TR,
                                         model_serial_correlations=True),
                            name="%s_level1design" % task)
    level1design.inputs.contrasts=subject_info.contrasts
    # FEATmodel generates an FSL design matrix
    level1model = Node(fsl.FEATModel(), name="%s_FEATModel" % task)

    # FILMGLs
    # smooth_autocorr, check default, use FSL default
    filmgls = Node(fsl.FILMGLS(threshold=1000), name="%s_GLS" % task)
    
    wf = Workflow(name=name)
    wf.connect([(modelspec, level1design, [('session_info','session_info')]),
                (level1design, level1model, [('ev_files', 'ev_files'),
                                             ('fsf_files','fsf_file')]),
                (level1model, datasink, [('design_file', '%s.@design_file' % name)]),
                (level1model, filmgls, [('design_file', 'design_file'),
                                        ('con_file', 'tcon_file'),
                                        ('fcon_file', 'fcon_file')]),
                (filmgls, datasink, [('copes', '%s.@copes' % name),
                                     ('zstats', '%s.@Z' % name),
                                     ('fstats', '%s.@F' % name),
                                     ('tstats','%s.@T' % name),
                                     ('param_estimates','%s.@param_estimates' % name),
                                     ('residual4d', '%s.@residual4d' % name),
                                     ('sigmasquareds', '%s.@sigmasquareds' % name)])
               ])
    return wf



                
def get_task_wfs(task, beta_subjectinfo=None, contrast_subjectinfo=None, regress_rt=True):
    rt_suffix = 'rt' if regress_rt==True else 'nort'
    # set up workflow lookup
    wf_dict = {'contrast': (init_GLM_wf, {'wf_label': 'model-%s_wf-contrast' % rt_suffix,
                                          'task': task,
                                          'derivs': True}), 
               'beta': (init_GLM_wf, {'wf_label': 'model-%s_wf-beta' % rt_suffix,
                                      'task': task,
                                      'derivs': False})}
    
    workflows = []
    if beta_subjectinfo:
        save_directory = join(first_level_dir, subject_id, task, 'model-%s' % rt_suffix, 'wf-beta')
        save_subjectinfo(save_directory, beta_subjectinfo)
        func, kwargs = wf_dict['beta']
        workflows.append(func(beta_subjectinfo, **kwargs))
    if contrast_subjectinfo:
        save_directory = join(first_level_dir, subject_id, task, 'model-%s' % rt_suffix, 'wf-contrast')
        save_subjectinfo(save_directory, contrast_subjectinfo)
        func, kwargs = wf_dict['contrast']
        workflows.append(func(contrast_subjectinfo, **kwargs))
    return workflows

# %%
# Initiation of the 1st-level analysis workflow
l1analysis = Workflow(name='%s_l1analysis' % subject_id)
l1analysis.base_dir = working_dir
for task in task_list:
    init_common_wf(l1analysis, task)
    # get nodes to pass
    masker = l1analysis.get_node('%s_masker' % task)
    # get info to pass to task workflows
    events_df, regressors, regressor_names = get_events_regressors(data_dir, fmriprep_dir,
                                                                   subject_id, task)
    # perform analyses both by regressing rt and not
    regress_rt_conditions = [False, True]
    if 'stop' in task:
        regress_rt_conditions = [False]
    betainfo = None; contrastinfo = None
    for regress_rt in regress_rt_conditions:
        if run_beta:
            betainfo = getsubjectinfo(events_df, regressors, regressor_names, task='beta', regress_rt=regress_rt)
        if run_contrast:
            contrastinfo = getsubjectinfo(events_df, regressors, regressor_names, task=task, regress_rt=regress_rt)
        task_workflows = get_task_wfs(task, betainfo, contrastinfo, regress_rt)
        for wf in task_workflows:
            l1analysis.connect([
                                (masker, wf, [('out_file', '%s_modelspec.functional_runs' % task)]),
                                (masker, wf, [('out_file','%s_GLS.in_file' % task)])
                                ])

# %% [markdown]
# ### Run the Workflow

# %%
#l1analysis.run()
l1analysis.run('MultiProc', plugin_args={'n_procs': n_procs})
# Out:
# 180513-19:58:51,584 workflow INFO:
# 	 Workflow s130_l1analysis settings: ['check', 'execution', 'logging', 'monitoring']
# 180513-19:58:51,616 workflow INFO:
# 	 Running in parallel.
# 180513-19:58:51,618 workflow INFO:
# 	 Currently running 0 tasks, and 1 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 4/4
# 180513-19:58:51,621 workflow INFO:
# 	 Executing node s130_l1analysis.stroop_selectFiles in dir: /home/ian/tmp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_selectFiles
# 180513-19:58:51,627 workflow INFO:
# 	 Running node "stroop_selectFiles" ("nipype.interfaces.io.SelectFiles").
# 180513-19:58:53,625 workflow INFO:
# 	 [Job finished] jobname: stroop_selectFiles jobid: 0
# 180513-19:58:53,629 workflow INFO:
# 	 Currently running 0 tasks, and 1 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 4/4
# 180513-19:58:53,632 workflow INFO:
# 	 Executing node s130_l1analysis.stroop_masker in dir: /home/ian/tmp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_masker
# 180513-19:58:53,640 workflow INFO:
# 	 Running node "stroop_masker" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /home/ian/tmp/fmri/derivatives/fmriprep/fmriprep/sub-s130/ses-1/func/sub-s130_ses-1_task-stroop_run-1_bold_space-MNI152NLin2009cAsym_preproc.nii.gz -mas /home/ian/tmp/fmri/derivatives/fmriprep/fmriprep/sub-s130/ses-1/func/sub-s130_ses-1_task-stroop_run-1_bold_space-MNI152NLin2009cAsym_brainmask.nii.gz /media/Data/Ian/Temp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_masker/sub-s130_ses-1_task-stroop_run-1_bold_space-MNI152NLin2009cAsym_preproc_masked.nii.gz.
# 180513-19:58:55,634 workflow INFO:
# 	 Currently running 1 tasks, and 0 jobs ready. Free memory (GB): 28.03/28.23, Free processors: 3/4
# 180513-19:59:17,665 workflow INFO:
# 	 [Job finished] jobname: stroop_masker jobid: 1
# 180513-19:59:17,675 workflow INFO:
# 	 Currently running 0 tasks, and 4 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 4/4
# 180513-19:59:17,706 workflow INFO:
# 	 Executing node s130_l1analysis.stroop_model-nort_wf-beta.stroop_modelspec in dir: /home/ian/tmp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-nort_wf-beta/stroop_modelspec
# 180513-19:59:17,716 workflow INFO:
# 	 Executing node s130_l1analysis.stroop_model-nort_wf-contrast.stroop_modelspec in dir: /home/ian/tmp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-nort_wf-contrast/stroop_modelspec
# 180513-19:59:17,727 workflow INFO:
# 	 Executing node s130_l1analysis.stroop_model-rt_wf-beta.stroop_modelspec in dir: /home/ian/tmp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-rt_wf-beta/stroop_modelspec
# 180513-19:59:17,743 workflow INFO:
# 	 Executing node s130_l1analysis.stroop_model-rt_wf-contrast.stroop_modelspec in dir: /home/ian/tmp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-rt_wf-contrast/stroop_modelspec
# 180513-19:59:17,786 workflow INFO:
# 	 Running node "stroop_modelspec" ("nipype.algorithms.modelgen.SpecifyModel").
# 180513-19:59:17,801 workflow INFO:
# 	 Running node "stroop_modelspec" ("nipype.algorithms.modelgen.SpecifyModel").
# 180513-19:59:17,818 workflow INFO:
# 	 Running node "stroop_modelspec" ("nipype.algorithms.modelgen.SpecifyModel").
# 180513-19:59:17,830 workflow INFO:
# 	 Running node "stroop_modelspec" ("nipype.algorithms.modelgen.SpecifyModel").
# 180513-19:59:19,745 workflow INFO:
# 	 [Job finished] jobname: stroop_modelspec jobid: 2
# 180513-19:59:19,748 workflow INFO:
# 	 [Job finished] jobname: stroop_modelspec jobid: 7
# 180513-19:59:19,751 workflow INFO:
# 	 [Job finished] jobname: stroop_modelspec jobid: 12
# 180513-19:59:19,753 workflow INFO:
# 	 [Job finished] jobname: stroop_modelspec jobid: 17
# 180513-19:59:19,757 workflow INFO:
# 	 Currently running 0 tasks, and 4 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 4/4
# 180513-19:59:19,838 workflow INFO:
# 	 Executing node s130_l1analysis.stroop_model-nort_wf-beta.stroop_level1design in dir: /home/ian/tmp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-nort_wf-beta/stroop_level1design
# 180513-19:59:19,894 workflow INFO:
# 	 Executing node s130_l1analysis.stroop_model-nort_wf-contrast.stroop_level1design in dir: /home/ian/tmp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-nort_wf-contrast/stroop_level1design
# 180513-19:59:19,970 workflow INFO:
# 	 Executing node s130_l1analysis.stroop_model-rt_wf-beta.stroop_level1design in dir: /home/ian/tmp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-rt_wf-beta/stroop_level1design180513-19:59:19,971 workflow INFO:
# 	 Running node "stroop_level1design" ("nipype.interfaces.fsl.model.Level1Design").
#
# 180513-19:59:20,34 workflow INFO:
# 	 Executing node s130_l1analysis.stroop_model-rt_wf-contrast.stroop_level1design in dir: /home/ian/tmp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-rt_wf-contrast/stroop_level1design
# 180513-19:59:20,36 workflow INFO:
# 	 Running node "stroop_level1design" ("nipype.interfaces.fsl.model.Level1Design").
# 180513-19:59:20,135 workflow INFO:
# 	 Running node "stroop_level1design" ("nipype.interfaces.fsl.model.Level1Design").
# 180513-19:59:20,171 workflow INFO:
# 	 Running node "stroop_level1design" ("nipype.interfaces.fsl.model.Level1Design").
# 180513-19:59:22,35 workflow INFO:
# 	 [Job finished] jobname: stroop_level1design jobid: 3
# 180513-19:59:22,40 workflow INFO:
# 	 [Job finished] jobname: stroop_level1design jobid: 8
# 180513-19:59:22,48 workflow INFO:
# 	 [Job finished] jobname: stroop_level1design jobid: 13
# 180513-19:59:22,52 workflow INFO:
# 	 [Job finished] jobname: stroop_level1design jobid: 18
# 180513-19:59:22,58 workflow INFO:
# 	 Currently running 0 tasks, and 4 jobs ready. Free memory (GB): 28.23/28.23, Free processors: 4/4
# 180513-19:59:22,116 workflow INFO:
# 	 Executing node s130_l1analysis.stroop_model-nort_wf-beta.stroop_FEATModel in dir: /home/ian/tmp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-nort_wf-beta/stroop_FEATModel
# 180513-19:59:22,123 workflow INFO:
# 	 Executing node s130_l1analysis.stroop_model-nort_wf-contrast.stroop_FEATModel in dir: /home/ian/tmp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-nort_wf-contrast/stroop_FEATModel
# 180513-19:59:22,141 workflow INFO:
# 	 Running node "stroop_FEATModel" ("nipype.interfaces.fsl.model.FEATModel"), a CommandLine Interface with command:
# feat_model run0 .
# 180513-19:59:22,158 workflow INFO:
# 	 Executing node s130_l1analysis.stroop_model-rt_wf-beta.stroop_FEATModel in dir: /home/ian/tmp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-rt_wf-beta/stroop_FEATModel
# 180513-19:59:22,170 workflow INFO:
# 	 Executing node s130_l1analysis.stroop_model-rt_wf-contrast.stroop_FEATModel in dir: /home/ian/tmp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-rt_wf-contrast/stroop_FEATModel
# 180513-19:59:22,197 workflow INFO:
# 	 Running node "stroop_FEATModel" ("nipype.interfaces.fsl.model.FEATModel"), a CommandLine Interface with command:
# feat_model run0 .
# 180513-19:59:22,217 workflow INFO:
# 	 Running node "stroop_FEATModel" ("nipype.interfaces.fsl.model.FEATModel"), a CommandLine Interface with command:
# feat_model run0 .
# 180513-19:59:22,265 workflow INFO:
# 	 Running node "stroop_FEATModel" ("nipype.interfaces.fsl.model.FEATModel"), a CommandLine Interface with command:
# feat_model run0 .
# 180513-19:59:24,171 workflow INFO:
# 	 [Job finished] jobname: stroop_FEATModel jobid: 9
# 180513-19:59:24,173 workflow INFO:
# 	 [Job finished] jobname: stroop_FEATModel jobid: 19
# 180513-19:59:24,175 workflow INFO:
# 	 Currently running 2 tasks, and 2 jobs ready. Free memory (GB): 27.83/28.23, Free processors: 2/4
# 180513-19:59:24,180 workflow INFO:
# 	 Executing node s130_l1analysis.stroop_model-nort_wf-contrast.stroop_GLS in dir: /home/ian/tmp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-nort_wf-contrast/stroop_GLS
# 180513-19:59:24,184 workflow INFO:
# 	 Executing node s130_l1analysis.stroop_model-rt_wf-contrast.stroop_GLS in dir: /home/ian/tmp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-rt_wf-contrast/stroop_GLS180513-19:59:24,185 workflow INFO:
# 	 Running node "stroop_GLS" ("nipype.interfaces.fsl.model.FILMGLS"), a CommandLine Interface with command:
# film_gls --rn=results --con=/media/Data/Ian/Temp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-nort_wf-contrast/stroop_FEATModel/run0.con --in=/media/Data/Ian/Temp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_masker/sub-s130_ses-1_task-stroop_run-1_bold_space-MNI152NLin2009cAsym_preproc_masked.nii.gz --pd=/media/Data/Ian/Temp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-nort_wf-contrast/stroop_FEATModel/run0.mat --thr=1000.000000.
#
# 180513-19:59:24,191 workflow INFO:
# 	 Running node "stroop_GLS" ("nipype.interfaces.fsl.model.FILMGLS"), a CommandLine Interface with command:
# film_gls --rn=results --con=/media/Data/Ian/Temp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-rt_wf-contrast/stroop_FEATModel/run0.con --in=/media/Data/Ian/Temp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_masker/sub-s130_ses-1_task-stroop_run-1_bold_space-MNI152NLin2009cAsym_preproc_masked.nii.gz --pd=/media/Data/Ian/Temp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-rt_wf-contrast/stroop_FEATModel/run0.mat --thr=1000.000000.
# 180513-19:59:26,186 workflow INFO:
# 	 Currently running 4 tasks, and 0 jobs ready. Free memory (GB): 27.43/28.23, Free processors: 0/4
# 180513-20:00:04,248 workflow INFO:
# 	 [Job finished] jobname: stroop_FEATModel jobid: 4
# 180513-20:00:04,250 workflow INFO:
# 	 Currently running 3 tasks, and 1 jobs ready. Free memory (GB): 27.63/28.23, Free processors: 1/4
# 180513-20:00:04,255 workflow INFO:
# 	 Executing node s130_l1analysis.stroop_model-nort_wf-beta.stroop_GLS in dir: /home/ian/tmp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-nort_wf-beta/stroop_GLS
# 180513-20:00:04,263 workflow INFO:
# 	 Running node "stroop_GLS" ("nipype.interfaces.fsl.model.FILMGLS"), a CommandLine Interface with command:
# film_gls --rn=results --con=/media/Data/Ian/Temp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-nort_wf-beta/stroop_FEATModel/run0.con --in=/media/Data/Ian/Temp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_masker/sub-s130_ses-1_task-stroop_run-1_bold_space-MNI152NLin2009cAsym_preproc_masked.nii.gz --pd=/media/Data/Ian/Temp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-nort_wf-beta/stroop_FEATModel/run0.mat --thr=1000.000000.
# 180513-20:00:06,257 workflow INFO:
# 	 [Job finished] jobname: stroop_FEATModel jobid: 14
# 180513-20:00:06,259 workflow INFO:
# 	 Currently running 3 tasks, and 1 jobs ready. Free memory (GB): 27.63/28.23, Free processors: 1/4
# 180513-20:00:06,263 workflow INFO:
# 	 Executing node s130_l1analysis.stroop_model-rt_wf-beta.stroop_GLS in dir: /home/ian/tmp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-rt_wf-beta/stroop_GLS
# 180513-20:00:06,268 workflow INFO:
# 	 Running node "stroop_GLS" ("nipype.interfaces.fsl.model.FILMGLS"), a CommandLine Interface with command:
# film_gls --rn=results --con=/media/Data/Ian/Temp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-rt_wf-beta/stroop_FEATModel/run0.con --in=/media/Data/Ian/Temp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_masker/sub-s130_ses-1_task-stroop_run-1_bold_space-MNI152NLin2009cAsym_preproc_masked.nii.gz --pd=/media/Data/Ian/Temp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-rt_wf-beta/stroop_FEATModel/run0.mat --thr=1000.000000.
# 180513-20:00:08,266 workflow INFO:
# 	 Currently running 4 tasks, and 0 jobs ready. Free memory (GB): 27.43/28.23, Free processors: 0/4
# 180513-20:27:48,751 workflow INFO:
# 	 [Job finished] jobname: stroop_GLS jobid: 10
# 180513-20:27:48,753 workflow INFO:
# 	 Currently running 3 tasks, and 1 jobs ready. Free memory (GB): 27.63/28.23, Free processors: 1/4
# 180513-20:27:48,770 workflow INFO:
# 	 Executing node s130_l1analysis.stroop_model-nort_wf-contrast.datasink in dir: /home/ian/tmp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-nort_wf-contrast/datasink
# 180513-20:27:48,784 workflow INFO:
# 	 Running node "datasink" ("nipype.interfaces.io.DataSink").
# 180513-20:27:48,789 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/run0.mat -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/designfile.mat
# 180513-20:27:48,792 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/cope1.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/cope1.nii.gz
# 180513-20:27:48,795 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/zstat1.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/zstat1.nii.gz
# 180513-20:27:48,797 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/tstat1.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/tstat1.nii.gz
# 180513-20:27:48,800 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe1.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe1.nii.gz
# 180513-20:27:48,804 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe2.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe2.nii.gz
# 180513-20:27:48,807 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe3.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe3.nii.gz
# 180513-20:27:48,809 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe4.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe4.nii.gz
# 180513-20:27:48,812 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe5.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe5.nii.gz
# 180513-20:27:48,814 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe6.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe6.nii.gz
# 180513-20:27:48,816 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe7.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe7.nii.gz
# 180513-20:27:48,818 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe8.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe8.nii.gz
# 180513-20:27:48,821 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe9.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe9.nii.gz
# 180513-20:27:48,824 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe10.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe10.nii.gz
# 180513-20:27:48,827 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe11.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe11.nii.gz
# 180513-20:27:48,830 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe12.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe12.nii.gz
# 180513-20:27:48,833 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe13.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe13.nii.gz
# 180513-20:27:48,836 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe14.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe14.nii.gz
# 180513-20:27:48,839 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe15.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe15.nii.gz
# 180513-20:27:48,842 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe16.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe16.nii.gz
# 180513-20:27:48,845 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe17.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe17.nii.gz
# 180513-20:27:48,851 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe18.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe18.nii.gz
# 180513-20:27:48,855 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe19.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe19.nii.gz
# 180513-20:27:48,858 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe20.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe20.nii.gz
# 180513-20:27:48,861 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe21.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe21.nii.gz
# 180513-20:27:48,865 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe22.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe22.nii.gz
# 180513-20:27:48,868 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe23.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe23.nii.gz
# 180513-20:27:48,871 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/pe24.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/pe24.nii.gz
# 180513-20:27:48,875 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/res4d.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/res4d.nii.gz
# 180513-20:27:48,877 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-nort_wf-contrast/sigmasquareds.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-nort/wf-contrast/sigmasquareds.nii.gz
# 180513-20:27:50,772 workflow INFO:
# 	 [Job finished] jobname: datasink jobid: 11
# 180513-20:27:50,774 workflow INFO:
# 	 Currently running 3 tasks, and 0 jobs ready. Free memory (GB): 27.63/28.23, Free processors: 1/4
# 180513-20:30:18,972 workflow INFO:
# 	 [Job finished] jobname: stroop_GLS jobid: 20
# 180513-20:30:18,973 workflow INFO:
# 	 Currently running 2 tasks, and 1 jobs ready. Free memory (GB): 27.83/28.23, Free processors: 2/4
# 180513-20:30:18,989 workflow INFO:
# 	 Executing node s130_l1analysis.stroop_model-rt_wf-contrast.datasink in dir: /home/ian/tmp/fmri/derivatives/1stLevel_workingdir/s130_l1analysis/stroop_model-rt_wf-contrast/datasink
# 180513-20:30:19,6 workflow INFO:
# 	 Running node "datasink" ("nipype.interfaces.io.DataSink").
# 180513-20:30:19,8 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/run0.mat -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/designfile.mat
# 180513-20:30:19,11 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/cope1.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/cope1.nii.gz
# 180513-20:30:19,12 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/cope2.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/cope2.nii.gz
# 180513-20:30:19,14 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/zstat1.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/zstat1.nii.gz
# 180513-20:30:19,17 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/zstat2.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/zstat2.nii.gz
# 180513-20:30:19,19 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/tstat1.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/tstat1.nii.gz
# 180513-20:30:19,21 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/tstat2.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/tstat2.nii.gz
# 180513-20:30:19,23 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe1.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe1.nii.gz
# 180513-20:30:19,25 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe2.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe2.nii.gz
# 180513-20:30:19,27 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe3.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe3.nii.gz
# 180513-20:30:19,29 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe4.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe4.nii.gz
# 180513-20:30:19,31 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe5.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe5.nii.gz
# 180513-20:30:19,33 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe6.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe6.nii.gz
# 180513-20:30:19,36 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe7.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe7.nii.gz
# 180513-20:30:19,39 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe8.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe8.nii.gz
# 180513-20:30:19,41 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe9.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe9.nii.gz
# 180513-20:30:19,43 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe10.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe10.nii.gz
# 180513-20:30:19,45 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe11.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe11.nii.gz
# 180513-20:30:19,49 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe12.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe12.nii.gz
# 180513-20:30:19,50 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe13.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe13.nii.gz
# 180513-20:30:19,52 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe14.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe14.nii.gz
# 180513-20:30:19,58 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe15.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe15.nii.gz
# 180513-20:30:19,60 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe16.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe16.nii.gz
# 180513-20:30:19,62 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe17.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe17.nii.gz
# 180513-20:30:19,64 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe18.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe18.nii.gz
# 180513-20:30:19,66 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe19.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe19.nii.gz
# 180513-20:30:19,68 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe20.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe20.nii.gz
# 180513-20:30:19,70 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe21.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe21.nii.gz
# 180513-20:30:19,72 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe22.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe22.nii.gz
# 180513-20:30:19,74 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe23.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe23.nii.gz
# 180513-20:30:19,77 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe24.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe24.nii.gz
# 180513-20:30:19,79 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe25.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe25.nii.gz
# 180513-20:30:19,81 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/pe26.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/pe26.nii.gz
# 180513-20:30:19,83 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/res4d.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/res4d.nii.gz
# 180513-20:30:19,85 interface INFO:
# 	 sub: /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop_model-rt_wf-contrast/sigmasquareds.nii.gz -> /home/ian/tmp/fmri/derivatives/1stLevel/s130/stroop/model-rt/wf-contrast/sigmasquareds.nii.gz
# 180513-20:30:20,990 workflow INFO:
# 	 [Job finished] jobname: datasink jobid: 21
# 180513-20:30:20,991 workflow INFO:
# 	 Currently running 2 tasks, and 0 jobs ready. Free memory (GB): 27.83/28.23, Free processors: 2/4
