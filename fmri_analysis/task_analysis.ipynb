# %% [markdown]
# ### Imports

# %%
# %pylab inline
import cPickle
from glob import glob
from nipype.interfaces import afni
from nipype.interfaces.fsl import Level1Design, FEATModel, FILMGLS, FEAT, maths
from nipype.algorithms.modelgen import SpecifyModel
from nipype.interfaces.utility import Function, IdentityInterface
from nipype.interfaces.io import SelectFiles, DataSink
from nipype.pipeline.engine import Workflow, Node
from os.path import abspath, join
import pandas as pd
import shutil
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Experiment Variables

# %%
experiment_dir = abspath('.')
output_dir = 'datasink'
working_dir = 'workingdir'

# list of subject identifiers
subject_list = ['sub-s358']

# list of task identifiers
task_list = ['ANT', 'DPX', 'stroop', 'twoByTwo']
task_list = ['ANT', 'stroop']

# TR of functional images
TR = .68

# %% [markdown]
# # Set up Nodes

# %% [markdown]
# ### Specify GLM Model for Stroop Contrasts

# %%
# helper function to create bunch
def subjectinfo(subject_id, task, inspect_inputs=False):
    
    from glob import glob
    import numpy as np
    import pandas as pd
    from os.path import join
    from nipype.interfaces.base import Bunch
    from utils.utils import get_contrasts, parse_EVs, process_confounds
    
    base_dir = '/home/jovyan/work/output'
    
    # strip "sub" from beginning of subject_id if provided
    subject_id = subject_id.replace('sub-','')
    
    ## Get the Events File
    
    # Read the TSV file and convert to pandas dataframe
    event_file = glob(join(base_dir,
                           'Data',
                           'sub-%s' % subject_id,
                           '*', 'func',
                           '*%s*events.tsv' % task))[0]
    events_df = pd.read_csv(event_file,sep = '\t')

    ## Get the Confounds File (output of fmriprep)
    # Read the TSV file and convert to pandas dataframe
    confounds_file = glob(join(base_dir,
                               'Data',
                               'sub-%s' % subject_id,
                               '*', 'func',
                               '*%s*confounds.tsv' % task))[0]
    regressors, regressor_names = process_confounds(confounds_file)
    
    # set up contrasts
    conditions, onsets, durations, amplitudes = parse_EVs(events_df,task)
    
    subjectinfo = Bunch(conditions=conditions,
                        onsets=onsets,
                         durations=durations,
                         amplitudes=amplitudes,
                         tmod=None,
                         pmod=None,
                         regressor_names=regressor_names,
                         regressors=regressors.T.tolist())
    if inspect_inputs==True:
        regressors_df = pd.DataFrame(regressors, columns = regressor_names)
        return events_df, regressors_df
    else:
        contrasts = get_contrasts(task)
        return subjectinfo, contrasts  # this output will later be returned to infosource

# %% [markdown]
# View one events file used in subject info

# %%
bunch, contrasts = subjectinfo('s358','ANT')
events_df,confounds_df = subjectinfo('s358','ANT',True)
events_df.head()
# Out:
#        onset  duration  response_time  block_duration  correct      cue  \
# 0   3.512000     0.795          0.788        2100.000      1.0  spatial
# 1   6.119000     0.795          0.593        2100.000      1.0  spatial
# 2   8.724864     0.795          0.480        2100.136      1.0  spatial
# 3  11.331728     0.795          0.428        2100.272      1.0  spatial
# 4  13.938592     0.795          0.721        2100.408      1.0   double
#
#         experiment_exp_id  feedback_duration flanker_location  \
# 0  attention_network_task                NaN               up
# 1  attention_network_task                NaN               up
# 2  attention_network_task                NaN               up
# 3  attention_network_task                NaN               up
# 4  attention_network_task                NaN             down
#
#   flanker_middle_direction flanker_type  key_press  trial_num worker_id
# 0                     left  incongruent         89        0.0      s358
# 1                     left  incongruent         89        1.0      s358
# 2                    right    congruent         71        2.0      s358
# 3                    right    congruent         71        3.0      s358
# 4                    right  incongruent         71        4.0      s358

# %% [markdown]
# ### Specify Input and Output Stream

# %%
# Get Subject Info - get subject specific condition information
getsubjectinfo = Node(Function(input_names=['subject_id', 'task'],
                               output_names=['subject_info', 'contrasts'],
                               function=subjectinfo),
                      name='getsubjectinfo')

# Infosource - a function free node to iterate over the list of subject names
infosource = Node(IdentityInterface(fields=['subject_id',
                                            'task',
                                            'contrasts']),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list),
                        ('task', task_list)]

# SelectFiles - to grab the data (alternativ to DataGrabber)
templates = {'func': join('Data', '{subject_id}','*','func',
                         '*{task}*preproc.nii.gz'),
            'mask': join('Data', '{subject_id}','*','func',
                         '*{task}*brainmask.nii.gz')}
selectfiles = Node(SelectFiles(templates,
                               base_directory = experiment_dir,
                               sort_filelist=True),
                   name="selectfiles")

# Datasink - creates output folder for important outputs
datasink = Node(DataSink(base_directory = experiment_dir,
                         container=output_dir),
                name="datasink")

# Use the following DataSink output substitutions
substitutions = [('_subject_id_', ''),
                ('fstat', 'FSTST'),
                ('run0.mat', 'designfile.mat')]
datasink.inputs.substitutions = substitutions

# %% [markdown]
# ### Model Specification

# %%
# mask and blur
masker = Node(maths.ApplyMask(),name='masker')

# SpecifyModel - Generates FSL-specific Model
modelspec = Node(SpecifyModel(input_units='secs',
                              time_repetition=TR,
                              high_pass_filter_cutoff=80),
                 name="modelspec")

# Level1Design - Generates an FSL design matrix
level1design = Node(Level1Design(bases={'dgamma':{'derivs': True}},
                                 interscan_interval=TR,
                                 model_serial_correlations=True),
                    name="level1design")

# FEATmodel
level1model = Node(FEATModel(), name="FEATModel")

# FILMGLs
# smooth_autocorr, check default, use FSL default
filmgls = Node(FILMGLS(), name="FILMGLS")

# %% [markdown]
# # Run as separate nodes
#
# Useful for debugging

# %% [raw]
# task = 'twoByTwo'
# getsubjectinfo.inputs.subject_id = 'sub-s358'
# getsubjectinfo.inputs.task = task
# subject_info_out = getsubjectinfo.run()
# subject_info = subject_info_out.outputs.subject_info
#
# selectfiles.inputs.subject_id = 'sub-s358'
# selectfiles.inputs.task = task
# selectfiles_out = selectfiles.run()
#
# masker.inputs.in_file = selectfiles_out.outputs.func
# masker.inputs.mask_file = selectfiles_out.outputs.mask
# masker_out = masker.run()
#
# modelspec.inputs.subject_info = subject_info
# modelspec.inputs.functional_runs = masker_out.outputs.out_file
# modelspec_out = modelspec.run()
#
# level1design.inputs.contrasts = subject_info_out.outputs.contrasts
# level1design.inputs.session_info = modelspec_out.outputs.session_info
# level1design_out = level1design.run()
# level1design_out.outputs
#
# level1model.inputs.fsf_file = level1design_out.outputs.fsf_files
# level1model.inputs.ev_files = level1design_out.outputs.ev_files
# out=level1model.run()
#
# #filmgls.inputs.in_file = masker_out.outputs.out_file
# #filmgls.inputs.design_file = out.outputs.design_file
# #filmgls.inputs.tcon_file = out.outputs.con_file
# #filmgls.inputs.fcon_file = out.outputs.fcon_file
# #fil_out = filmgls.run()

# %% [raw]
# desmtx=numpy.loadtxt(out.outputs.design_file,skiprows=5)
# plt.imshow(desmtx,aspect='auto',interpolation='nearest',cmap='gray')
# plt.title('Design Matrix')
# plt.show()
# cc=numpy.corrcoef(desmtx.T)
# plt.imshow(cc,aspect='auto',interpolation='nearest', cmap=plt.cm.viridis)
# plt.colorbar()
# plt.title('Correlation of Regressors')
# plt.show()
# # show first regressors
# plt.figure(figsize=[16,6])
# colors = ['m','c']
# for designi, conti in [(0,0),(2,1)]:
#     plt.plot(desmtx[:,designi], c=colors[conti], label=subject_info.conditions[conti])
#     ax = plt.gca()
#     for i in subject_info.onsets[conti]:
#         plt.axvline(i/.68, ymin=0, ymax=.1, c=colors[conti])
# plt.legend()
# plt.title('Incongruent Regressors')

# %% [raw]
# import nilearn.plotting
# import nilearn.image
#
# nilearn.plotting.plot_glass_brain(nilearn.image.smooth_img(fil_out.outputs.zstats[0], 6),
#                                       display_mode='lyrz', colorbar=True, plot_abs=False, threshold=1)
#
# nilearn.plotting.plot_glass_brain(nilearn.image.smooth_img(fil_out.outputs.zstats[1], 6),
#                                       display_mode='lyrz', colorbar=True, plot_abs=False, threshold=1)
#
# nilearn.plotting.plot_glass_brain(nilearn.image.smooth_img(fil_out.outputs.zstats[2], 6),
#                                       display_mode='lyrz', colorbar=True, plot_abs=False, threshold=1)

# %% [markdown]
# # Workflow

# %%
# Initiation of the 1st-level analysis workflow
l1analysis = Workflow(name='l1analysis')
l1analysis.base_dir = join(experiment_dir, working_dir)

# Connect up the 1st-level analysis components
l1analysis.connect([(infosource, selectfiles, [('subject_id', 'subject_id'),
                                               ('task', 'task')]),
                    (infosource, getsubjectinfo, [('subject_id','subject_id'),
                                                 ('task', 'task')]),
                    (selectfiles, masker, [('func','in_file'),
                                           ('mask', 'mask_file')]),
                    (getsubjectinfo, modelspec, [('subject_info','subject_info')]),
                    (masker, modelspec, [('out_file', 'functional_runs')]),
                    (modelspec, level1design, [('session_info','session_info')]),
                    (getsubjectinfo, level1design, [('contrasts','contrasts')]),
                    (level1design, level1model, [('ev_files', 'ev_files'),
                                                 ('fsf_files','fsf_file')]),
                    (masker, filmgls, [('out_file', 'in_file')]),
                    (level1model, filmgls, [('design_file', 'design_file'),
                                            ('con_file', 'tcon_file'),
                                            ('fcon_file', 'fcon_file')]),
                    (level1model, datasink, [('design_file', '1stLevel.@design_file')]),
                    (filmgls, datasink, [('zstats', '1stLevel.@Z'),
                                        ('fstats', '1stLevel.@F'),
                                        ('tstats','1stLevel.@T'),
                                        ('param_estimates','1stLevel.@param_estimates')])
                    ])

# %% [markdown]
# ### Run the Workflow

# %%
l1analysis.run('MultiProc', plugin_args={'n_procs': 4})
# Out:
# 170530-00:49:03,210 workflow INFO:
# 	 Workflow l1analysis settings: ['check', 'execution', 'logging']
# 170530-00:49:03,239 workflow INFO:
# 	 Running in parallel.
# 170530-00:49:03,250 workflow INFO:
# 	 Executing: selectfiles.a0 ID: 0
# 170530-00:49:03,259 workflow INFO:
# 	 Executing: getsubjectinfo.a0 ID: 2
# 170530-00:49:03,263 workflow INFO:
# 	 Executing: selectfiles.a1 ID: 3
# 170530-00:49:03,262 workflow INFO:
# 	 Executing node selectfiles.a0 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_ANT/selectfiles
# 170530-00:49:03,267 workflow INFO:
# 	 Executing: getsubjectinfo.a1 ID: 5
# 170530-00:49:03,267 workflow INFO:
# 	 Executing node getsubjectinfo.a0 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_ANT/getsubjectinfo
# 170530-00:49:03,275 workflow INFO:
# 	 Executing node getsubjectinfo.a1 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_stroop/getsubjectinfo
# 170530-00:49:03,271 workflow INFO:
# 	 Executing node selectfiles.a1 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_stroop/selectfiles
# 170530-00:49:03,339 workflow INFO:
# 	 [Job finished] jobname: selectfiles.a0 jobid: 0
# 170530-00:49:03,352 workflow INFO:
# 	 [Job finished] jobname: selectfiles.a1 jobid: 3
# 170530-00:49:03,360 workflow INFO:
# 	 Executing: masker.a0 ID: 1
# 170530-00:49:03,404 workflow INFO:
# 	 Executing node masker.a0 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_ANT/masker
# 170530-00:49:03,400 workflow INFO:
# 	 Executing: masker.a1 ID: 4
# 170530-00:49:03,429 workflow INFO:
# 	 Running: fslmaths /home/jovyan/work/output/Data/sub-s358/ses-1/func/sub-s358_ses-1_task-ANT_run-1_bold_space-MNI152NLin2009cAsym_preproc.nii.gz -mas /home/jovyan/work/output/Data/sub-s358/ses-1/func/sub-s358_ses-1_task-ANT_run-1_bold_space-MNI152NLin2009cAsym_brainmask.nii.gz /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_ANT/masker/sub-s358_ses-1_task-ANT_run-1_bold_space-MNI152NLin2009cAsym_preproc_masked.nii.gz
# 170530-00:49:03,429 workflow INFO:
# 	 Executing node masker.a1 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_stroop/masker
# 170530-00:49:03,478 workflow INFO:
# 	 Running: fslmaths /home/jovyan/work/output/Data/sub-s358/ses-2/func/sub-s358_ses-2_task-stroop_run-1_bold_space-MNI152NLin2009cAsym_preproc.nii.gz -mas /home/jovyan/work/output/Data/sub-s358/ses-2/func/sub-s358_ses-2_task-stroop_run-1_bold_space-MNI152NLin2009cAsym_brainmask.nii.gz /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_stroop/masker/sub-s358_ses-2_task-stroop_run-1_bold_space-MNI152NLin2009cAsym_preproc_masked.nii.gz
# 170530-00:49:03,878 workflow INFO:
# 	 [Job finished] jobname: getsubjectinfo.a1 jobid: 5
# 170530-00:49:04,162 workflow INFO:
# 	 [Job finished] jobname: getsubjectinfo.a0 jobid: 2
# 170530-00:49:38,974 workflow INFO:
# 	 [Job finished] jobname: masker.a1 jobid: 4
# 170530-00:49:38,979 workflow INFO:
# 	 Executing: modelspec.a1 ID: 11
# 170530-00:49:39,144 workflow INFO:
# 	 Executing node modelspec.a1 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_stroop/modelspec
# 170530-00:49:40,559 workflow INFO:
# 	 [Job finished] jobname: modelspec.a1 jobid: 11
# 170530-00:49:40,563 workflow INFO:
# 	 Executing: level1design.a1 ID: 12
# 170530-00:49:41,39 workflow INFO:
# 	 Executing node level1design.a1 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_stroop/level1design
# 170530-00:49:42,163 workflow INFO:
# 	 [Job finished] jobname: level1design.a1 jobid: 12
# 170530-00:49:42,167 workflow INFO:
# 	 Executing: FEATModel.a1 ID: 13
# 170530-00:49:42,379 workflow INFO:
# 	 Executing node FEATModel.a1 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_stroop/FEATModel
# 170530-00:49:42,431 workflow INFO:
# 	 Running: feat_model run0
# 170530-00:49:43,593 workflow INFO:
# 	 [Job finished] jobname: FEATModel.a1 jobid: 13
# 170530-00:49:43,598 workflow INFO:
# 	 Executing: FILMGLS.a1 ID: 14
# 170530-00:49:43,614 workflow INFO:
# 	 Executing node FILMGLS.a1 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_stroop/FILMGLS
# 170530-00:49:43,625 workflow INFO:
# 	 Running: film_gls --rn=results --con=/home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_stroop/FEATModel/run0.con --in=/home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_stroop/masker/sub-s358_ses-2_task-stroop_run-1_bold_space-MNI152NLin2009cAsym_preproc_masked.nii.gz --pd=/home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_stroop/FEATModel/run0.mat --thr=0.000000
# 170530-00:50:06,615 workflow INFO:
# 	 [Job finished] jobname: masker.a0 jobid: 1
# 170530-00:50:06,620 workflow INFO:
# 	 Executing: modelspec.a0 ID: 6
# 170530-00:50:06,888 workflow INFO:
# 	 Executing node modelspec.a0 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_ANT/modelspec
# 170530-00:50:09,254 workflow INFO:
# 	 [Job finished] jobname: modelspec.a0 jobid: 6
# 170530-00:50:09,259 workflow INFO:
# 	 Executing: level1design.a0 ID: 7
# 170530-00:50:10,5 workflow INFO:
# 	 Executing node level1design.a0 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_ANT/level1design
# 170530-00:50:11,871 workflow INFO:
# 	 [Job finished] jobname: level1design.a0 jobid: 7
# 170530-00:50:11,877 workflow INFO:
# 	 Executing: FEATModel.a0 ID: 8
# 170530-00:50:12,179 workflow INFO:
# 	 Executing node FEATModel.a0 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_ANT/FEATModel
# 170530-00:50:12,206 workflow INFO:
# 	 Running: feat_model run0
# 170530-00:50:14,342 workflow INFO:
# 	 [Job finished] jobname: FEATModel.a0 jobid: 8
# 170530-00:50:14,346 workflow INFO:
# 	 Executing: FILMGLS.a0 ID: 9
# 170530-00:50:14,375 workflow INFO:
# 	 Executing node FILMGLS.a0 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_ANT/FILMGLS
# 170530-00:50:14,392 workflow INFO:
# 	 Running: film_gls --rn=results --con=/home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_ANT/FEATModel/run0.con --in=/home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_ANT/masker/sub-s358_ses-1_task-ANT_run-1_bold_space-MNI152NLin2009cAsym_preproc_masked.nii.gz --pd=/home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_ANT/FEATModel/run0.mat --thr=0.000000
# 170530-01:26:46,359 workflow INFO:
# 	 [Job finished] jobname: FILMGLS.a1 jobid: 14
# 170530-01:26:46,367 workflow INFO:
# 	 Executing: datasink.a1 ID: 15
# 170530-01:26:46,409 workflow INFO:
# 	 Executing node datasink.a1 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_stroop/datasink
# 170530-01:26:46,441 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe1.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe1.nii.gz
# 170530-01:26:46,454 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe2.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe2.nii.gz
# 170530-01:26:46,457 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe3.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe3.nii.gz
# 170530-01:26:46,462 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe4.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe4.nii.gz
# 170530-01:26:46,466 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe5.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe5.nii.gz
# 170530-01:26:46,473 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe6.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe6.nii.gz
# 170530-01:26:46,479 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe7.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe7.nii.gz
# 170530-01:26:46,489 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe8.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe8.nii.gz
# 170530-01:26:46,493 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe9.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe9.nii.gz
# 170530-01:26:46,496 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe10.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe10.nii.gz
# 170530-01:26:46,499 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe11.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe11.nii.gz
# 170530-01:26:46,502 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe12.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe12.nii.gz
# 170530-01:26:46,506 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe13.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe13.nii.gz
# 170530-01:26:46,509 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe14.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe14.nii.gz
# 170530-01:26:46,521 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe15.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe15.nii.gz
# 170530-01:26:46,524 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe16.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe16.nii.gz
# 170530-01:26:46,527 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe17.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe17.nii.gz
# 170530-01:26:46,530 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe18.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe18.nii.gz
# 170530-01:26:46,540 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe19.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe19.nii.gz
# 170530-01:26:46,545 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe20.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe20.nii.gz
# 170530-01:26:46,549 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe21.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe21.nii.gz
# 170530-01:26:46,554 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe22.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe22.nii.gz
# 170530-01:26:46,563 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe23.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe23.nii.gz
# 170530-01:26:46,567 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe24.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe24.nii.gz
# 170530-01:26:46,570 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe25.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe25.nii.gz
# 170530-01:26:46,574 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe26.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe26.nii.gz
# 170530-01:26:46,577 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe27.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe27.nii.gz
# 170530-01:26:46,585 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe28.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe28.nii.gz
# 170530-01:26:46,590 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/pe29.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/pe29.nii.gz
# 170530-01:26:46,602 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/tstat1.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/tstat1.nii.gz
# 170530-01:26:46,624 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/tstat2.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/tstat2.nii.gz
# 170530-01:26:46,640 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/tstat3.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/tstat3.nii.gz
# 170530-01:26:46,657 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/zstat1.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/zstat1.nii.gz
# 170530-01:26:46,668 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/zstat2.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/zstat2.nii.gz
# 170530-01:26:46,679 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/zstat3.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/zstat3.nii.gz
# 170530-01:26:46,690 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_stroop/run0.mat -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_stroop/designfile.mat
# 170530-01:26:46,773 workflow INFO:
# 	 [Job finished] jobname: datasink.a1 jobid: 15
# 170530-02:18:35,253 workflow INFO:
# 	 [Job finished] jobname: FILMGLS.a0 jobid: 9
# 170530-02:18:35,257 workflow INFO:
# 	 Executing: datasink.a0 ID: 10
# 170530-02:18:35,287 workflow INFO:
# 	 Executing node datasink.a0 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_ANT/datasink
# 170530-02:18:35,309 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe1.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe1.nii.gz
# 170530-02:18:35,311 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe2.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe2.nii.gz
# 170530-02:18:35,312 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe3.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe3.nii.gz
# 170530-02:18:35,313 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe4.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe4.nii.gz
# 170530-02:18:35,315 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe5.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe5.nii.gz
# 170530-02:18:35,317 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe6.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe6.nii.gz
# 170530-02:18:35,319 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe7.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe7.nii.gz
# 170530-02:18:35,322 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe8.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe8.nii.gz
# 170530-02:18:35,327 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe9.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe9.nii.gz
# 170530-02:18:35,332 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe10.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe10.nii.gz
# 170530-02:18:35,338 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe11.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe11.nii.gz
# 170530-02:18:35,342 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe12.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe12.nii.gz
# 170530-02:18:35,344 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe13.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe13.nii.gz
# 170530-02:18:35,351 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe14.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe14.nii.gz
# 170530-02:18:35,355 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe15.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe15.nii.gz
# 170530-02:18:35,357 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe16.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe16.nii.gz
# 170530-02:18:35,362 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe17.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe17.nii.gz
# 170530-02:18:35,370 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe18.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe18.nii.gz
# 170530-02:18:35,380 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe19.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe19.nii.gz
# 170530-02:18:35,386 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe20.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe20.nii.gz
# 170530-02:18:35,390 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe21.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe21.nii.gz
# 170530-02:18:35,394 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe22.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe22.nii.gz
# 170530-02:18:35,398 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe23.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe23.nii.gz
# 170530-02:18:35,403 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe24.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe24.nii.gz
# 170530-02:18:35,405 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe25.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe25.nii.gz
# 170530-02:18:35,408 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe26.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe26.nii.gz
# 170530-02:18:35,412 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe27.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe27.nii.gz
# 170530-02:18:35,415 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe28.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe28.nii.gz
# 170530-02:18:35,417 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe29.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe29.nii.gz
# 170530-02:18:35,424 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe30.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe30.nii.gz
# 170530-02:18:35,431 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/pe31.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/pe31.nii.gz
# 170530-02:18:35,435 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/tstat1.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/tstat1.nii.gz
# 170530-02:18:35,438 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/tstat2.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/tstat2.nii.gz
# 170530-02:18:35,441 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/tstat3.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/tstat3.nii.gz
# 170530-02:18:35,443 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/tstat4.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/tstat4.nii.gz
# 170530-02:18:35,445 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/tstat5.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/tstat5.nii.gz
# 170530-02:18:35,446 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/tstat6.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/tstat6.nii.gz
# 170530-02:18:35,448 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/zstat1.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/zstat1.nii.gz
# 170530-02:18:35,450 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/zstat2.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/zstat2.nii.gz
# 170530-02:18:35,452 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/zstat3.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/zstat3.nii.gz
# 170530-02:18:35,455 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/zstat4.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/zstat4.nii.gz
# 170530-02:18:35,456 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/zstat5.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/zstat5.nii.gz
# 170530-02:18:35,458 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/zstat6.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/zstat6.nii.gz
# 170530-02:18:35,460 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_ANT/run0.mat -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_ANT/designfile.mat
# 170530-02:18:35,500 workflow INFO:
# 	 [Job finished] jobname: datasink.a0 jobid: 10

# %% [markdown]
# ### Visualize Workflow

# %%
# Create 1st-level analysis output graph
l1analysis.write_graph(graph2use='colored', format='png', simple_form=True)
# Visualize the graph
from IPython.display import Image
graph_file=join(l1analysis.base_dir, 'l1analysis', 'graph.dot.png')
Image(graph_file)
try:
    shutil.move(graph_file, 'l1analysis')
except shutil.Error:
    pass
# remove working directory
shutil.rmtree(working_dir)
# Out:
# 170530-02:57:52,773 workflow INFO:
# 	 Converting dotfile: /home/jovyan/work/output/workingdir/l1analysis/graph.dot to png format

# %% [markdown]
# ### Visualize Design Matrix

# %%
# !tree datasink/1stLevel/sub*
# Out:
# datasink/1stLevel/sub-s358_task_ANT
# ├── designfile.mat
# ├── pe10.nii.gz
# ├── pe11.nii.gz
# ├── pe12.nii.gz
# ├── pe13.nii.gz
# ├── pe14.nii.gz
# ├── pe15.nii.gz
# ├── pe16.nii.gz
# ├── pe17.nii.gz
# ├── pe18.nii.gz
# ├── pe19.nii.gz
# ├── pe1.nii.gz
# ├── pe20.nii.gz
# ├── pe21.nii.gz
# ├── pe22.nii.gz
# ├── pe23.nii.gz
# ├── pe24.nii.gz
# ├── pe25.nii.gz
# ├── pe26.nii.gz
# ├── pe27.nii.gz
# ├── pe28.nii.gz
# ├── pe29.nii.gz
# ├── pe2.nii.gz
# ├── pe30.nii.gz
# ├── pe31.nii.gz
# ├── pe3.nii.gz
# ├── pe4.nii.gz
# ├── pe5.nii.gz
# ├── pe6.nii.gz
# ├── pe7.nii.gz
# ├── pe8.nii.gz
# ├── pe9.nii.gz
# ├── tstat1.nii.gz
# ├── tstat2.nii.gz
# ├── tstat3.nii.gz
# ├── tstat4.nii.gz
# ├── tstat5.nii.gz
# ├── tstat6.nii.gz
# ├── zstat1.nii.gz
# ├── zstat2.nii.gz
# ├── zstat3.nii.gz
# ├── zstat4.nii.gz
# ├── zstat5.nii.gz
# └── zstat6.nii.gz
# datasink/1stLevel/sub-s358_task_stroop
# ├── designfile.mat
# ├── pe10.nii.gz
# ├── pe11.nii.gz
# ├── pe12.nii.gz
# ├── pe13.nii.gz
# ├── pe14.nii.gz
# ├── pe15.nii.gz
# ├── pe16.nii.gz
# ├── pe17.nii.gz
# ├── pe18.nii.gz
# ├── pe19.nii.gz
# ├── pe1.nii.gz
# ├── pe20.nii.gz
# ├── pe21.nii.gz
# ├── pe22.nii.gz
# ├── pe23.nii.gz
# ├── pe24.nii.gz
# ├── pe25.nii.gz
# ├── pe26.nii.gz
# ├── pe27.nii.gz
# ├── pe28.nii.gz
# ├── pe29.nii.gz
# ├── pe2.nii.gz
# ├── pe3.nii.gz
# ├── pe4.nii.gz
# ├── pe5.nii.gz
# ├── pe6.nii.gz
# ├── pe7.nii.gz
# ├── pe8.nii.gz
# ├── pe9.nii.gz
# ├── tstat1.nii.gz
# ├── tstat2.nii.gz
# ├── tstat3.nii.gz
# ├── zstat1.nii.gz
# ├── zstat2.nii.gz
# └── zstat3.nii.gz
#
# 0 directories, 80 files

# %%
design_file = glob(join(experiment_dir,'datasink','1stLevel','sub-s358_task_ANT','designfile.mat'))[0]
desmtx=numpy.loadtxt(design_file, skiprows=5)
plt.imshow(desmtx,aspect='auto',interpolation='nearest',cmap='gray')
plt.title('Design Matrix')
plt.show()
cc=numpy.corrcoef(desmtx.T)
plt.imshow(cc,aspect='auto',interpolation='nearest', cmap=plt.cm.viridis)
plt.colorbar()
plt.title('Correlation of Regressors')
plt.show()
"""
# show first regressors
plt.figure(figsize=[20,8])
plt.plot(desmtx[:,0],'b', label=subject_info.conditions[0])
plt.plot(desmtx[:,2],'r', label=subject_info.conditions[1])
for i in subject_info.onsets[0]:
    plt.axvline(i/.68, ymin=0, ymax=.1)
for i in subject_info.onsets[1]:
    plt.axvline(i/.68, ymin=0, ymax=.1, c='r')
plt.legend()
plt.title('Congruent/Incongruent Regressors')
"""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-e270857bbbed> in <module>()
#      12 # show first regressors
#      13 plt.figure(figsize=[20,8])
# ---> 14 plt.plot(desmtx[:,0],'b', label=subject_info.conditions[0])
#      15 plt.plot(desmtx[:,2],'r', label=subject_info.conditions[1])
#      16 for i in subject_info.onsets[0]:
#
# NameError: name 'subject_info' is not defined

# %% [markdown]
# ### Visualize Results

# %%
from nilearn.plotting import plot_stat_map
from nilearn.image import smooth_img

anatimg = glob(join(experiment_dir,'Data','sub-s358','anat','*T1w*MNI*preproc*'))[0]
contrast_img = glob(join(experiment_dir,'datasink','1stLevel','sub-s358_task_ANT','zstat3.nii.gz'))[0]
plot_stat_map(smooth_img(contrast_img, 8), title='stroop effect',
              bg_img=anatimg, threshold=1, display_mode='z', cut_coords=(-30, -15, 0, 15, 30), dim=-1)
# Out:
# /opt/conda/envs/python2/lib/python2.7/site-packages/matplotlib/__init__.py:1401: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# /opt/conda/envs/python2/lib/python2.7/site-packages/nilearn/plotting/displays.py:649: UserWarning: empty mask
#   get_mask_bounds(new_img_like(img, not_mask, affine))
# /opt/conda/envs/python2/lib/python2.7/site-packages/matplotlib/artist.py:879: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.
#   return func(v)

# %%
import nilearn.plotting
import nilearn.image
contrast_imgs = sort(glob(join(experiment_dir,'datasink','1stLevel','sub-s358_task_ANT','zstat*.nii.gz')))
for contrast_img in contrast_imgs:
    nilearn.plotting.plot_glass_brain(nilearn.image.smooth_img(contrast_img, 8),
                                      display_mode='lyrz', colorbar=True, plot_abs=False, threshold=0)
