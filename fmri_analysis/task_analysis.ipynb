# %% [markdown]
# ### Imports

# %%
# %pylab inline
from glob import glob
from nipype.interfaces import afni
from nipype.interfaces.fsl import Level1Design, FEATModel, FILMGLS, FEAT, maths
from nipype.algorithms.modelgen import SpecifyModel
from nipype.interfaces.utility import Function, IdentityInterface
from nipype.interfaces.io import SelectFiles, DataSink
from nipype.pipeline.engine import Workflow, Node
from os import makedirs
from os.path import abspath, join
import pandas as pd
import shutil
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Experiment Variables

# %%
experiment_dir = abspath('.')
output_dir = 'datasink'
working_dir = 'workingdir'

# list of subject identifiers
subject_list = ['sub-s358']

# list of task identifiers
task_list = ['ANT', 'CCTHot', 'DPX', 'stroop', 'twoByTwo']
task_list = ['CCTHot']

# TR of functional images
TR = .68

# %% [markdown]
# # Set up Nodes

# %% [markdown]
# ### Define helper functions

# %%
# helper function to create bunch
def subjectinfo(subject_id, task, inspect_inputs=False):
    
    from glob import glob
    import numpy as np
    import pandas as pd
    from os.path import join
    from nipype.interfaces.base import Bunch
    from utils.utils import get_contrasts, parse_EVs, process_confounds
    
    base_dir = '/home/jovyan/work/output'
    
    # strip "sub" from beginning of subject_id if provided
    subject_id = subject_id.replace('sub-','')
    
    ## Get the Events File
    
    # Read the TSV file and convert to pandas dataframe
    event_file = glob(join(base_dir,
                           'Data',
                           'sub-%s' % subject_id,
                           '*', 'func',
                           '*%s*events.tsv' % task))[0]
    events_df = pd.read_csv(event_file,sep = '\t')

    ## Get the Confounds File (output of fmriprep)
    # Read the TSV file and convert to pandas dataframe
    confounds_file = glob(join(base_dir,
                               'Data',
                               'sub-%s' % subject_id,
                               '*', 'func',
                               '*%s*confounds.tsv' % task))[0]
    regressors, regressor_names = process_confounds(confounds_file)
    
    # set up contrasts
    conditions, onsets, durations, amplitudes = parse_EVs(events_df,task)
    
    subjectinfo = Bunch(conditions=conditions,
                        onsets=onsets,
                         durations=durations,
                         amplitudes=amplitudes,
                         tmod=None,
                         pmod=None,
                         regressor_names=regressor_names,
                         regressors=regressors.T.tolist())
    if inspect_inputs==True:
        regressors_df = pd.DataFrame(regressors, columns = regressor_names)
        return events_df, regressors_df
    else:
        contrasts = get_contrasts(task)
        return subjectinfo, contrasts  # this output will later be returned to infosource

def save_subjectinfo(base_directory, subject_id, task, subject_info, contrasts):
    import errno
    from os import makedirs
    from os.path import join
    import cPickle
    task_dir = join(base_directory, '1stLevel', subject_id + '_task_' + task)
    try: 
        makedirs(task_dir)
    except OSError as e:
        if e.errno == errno.EEXIST:
            pass
        else:
            raise
    subjectinfo_path = join(task_dir,'subjectinfo.pkl')
    cPickle.dump(subject_info, open(subjectinfo_path,'w'))
    
    contrast_path = join(task_dir,'contrasts.pkl')
    cPickle.dump(contrasts, open(contrast_path,'w'))
    return (subjectinfo_path, contrast_path)

# %% [markdown]
# View one events file used in subject info

# %%
bunch, contrasts = subjectinfo('s358','CCTHot')
events_df,confounds_df = subjectinfo('s358','CCTHot',True)
events_df.head()
# Out:
#     onset  duration  response_time         EV     action  \
# 0   3.009     2.807          2.577  -1.410872  draw_card
# 1   5.588     2.807          1.071  -4.144206  draw_card
# 2   6.659     2.807          0.849  -8.244206  draw_card
# 3   7.510     2.807          2.211 -15.077539  end_round
# 4  12.179     2.807          2.631  -0.577539  draw_card
#
#          experiment_exp_id  gain_amount  gain_probability  key_press  \
# 0  columbia_card_task_fmri         12.0          0.833333       89.0
# 1  columbia_card_task_fmri         12.0          0.800000       89.0
# 2  columbia_card_task_fmri         12.0          0.750000       89.0
# 3  columbia_card_task_fmri         12.0          0.666667       71.0
# 4  columbia_card_task_fmri         14.0          0.833333       89.0
#
#    loss_amount  loss_probability  num_cards  num_click_in_round  \
# 0        -70.0          0.166667        6.0                 1.0
# 1        -70.0          0.200000        6.0                 2.0
# 2        -70.0          0.250000        6.0                 3.0
# 3        -70.0          0.333333        6.0                 4.0
# 4        -75.0          0.166667        6.0                 1.0
#
#    num_loss_cards      risk  total_cards worker_id feedback
# 0             1.0 -1.872734          NaN      s358     True
# 1             1.0  0.367597          NaN      s358     True
# 2             1.0  3.074563          NaN      s358     True
# 3             1.0  6.222617          3.0      s358     True
# 4             1.0  0.735928          NaN      s358     True

# %% [markdown]
# ### Specify Input and Output Stream

# %%
# Get Subject Info - get subject specific condition information
getsubjectinfo = Node(Function(input_names=['subject_id', 'task'],
                               output_names=['subject_info', 'contrasts'],
                               function=subjectinfo),
                      name='getsubjectinfo')

# Infosource - a function free node to iterate over the list of subject names
infosource = Node(IdentityInterface(fields=['subject_id',
                                            'task',
                                            'contrasts']),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list),
                        ('task', task_list)]

# SelectFiles - to grab the data (alternativ to DataGrabber)
templates = {'func': join('Data', '{subject_id}','*','func',
                         '*{task}*preproc.nii.gz'),
            'mask': join('Data', '{subject_id}','*','func',
                         '*{task}*brainmask.nii.gz')}
selectfiles = Node(SelectFiles(templates,
                               base_directory = experiment_dir,
                               sort_filelist=True),
                   name="selectfiles")

# Datasink - creates output folder for important outputs
datasink = Node(DataSink(base_directory = experiment_dir,
                         container=output_dir),
                name="datasink")

# Save python objects that aren't accomodated by datasink nodes
save_subjectinfo = Node(Function(input_names=['base_directory','subject_id',
                                              'task','subject_info','contrasts'],
                                 output_names=['output_path'],
                                function=save_subjectinfo),
                       name="savesubjectinfo")
save_subjectinfo.inputs.base_directory = join(experiment_dir,output_dir)
# Use the following DataSink output substitutions
substitutions = [('_subject_id_', ''),
                ('fstat', 'FSTST'),
                ('run0.mat', 'designfile.mat')]
datasink.inputs.substitutions = substitutions

# %% [markdown]
# ### Model Specification

# %%
# mask and blur
masker = Node(maths.ApplyMask(),name='masker')

# SpecifyModel - Generates FSL-specific Model
modelspec = Node(SpecifyModel(input_units='secs',
                              time_repetition=TR,
                              high_pass_filter_cutoff=80),
                 name="modelspec")

# Level1Design - Generates an FSL design matrix
level1design = Node(Level1Design(bases={'dgamma':{'derivs': True}},
                                 interscan_interval=TR,
                                 model_serial_correlations=True),
                    name="level1design")

# FEATmodel
level1model = Node(FEATModel(), name="FEATModel")

# FILMGLs
# smooth_autocorr, check default, use FSL default
filmgls = Node(FILMGLS(), name="FILMGLS")

# %% [markdown]
# # Run as separate nodes
#
# Useful for debugging

# %% [raw]
# task = 'WATT3'
# getsubjectinfo.inputs.subject_id = 'sub-s358'
# getsubjectinfo.inputs.task = task
# subject_info_out = getsubjectinfo.run()
# subject_info = subject_info_out.outputs.subject_info
#
# selectfiles.inputs.subject_id = 'sub-s358'
# selectfiles.inputs.task = task
# selectfiles_out = selectfiles.run()
#
# masker.inputs.in_file = selectfiles_out.outputs.func
# masker.inputs.mask_file = selectfiles_out.outputs.mask
# masker_out = masker.run()
#
# modelspec.inputs.subject_info = subject_info
# modelspec.inputs.functional_runs = masker_out.outputs.out_file
# modelspec_out = modelspec.run()
#
# level1design.inputs.contrasts = subject_info_out.outputs.contrasts
# level1design.inputs.session_info = modelspec_out.outputs.session_info
# level1design_out = level1design.run()
# level1design_out.outputs
#
# level1model.inputs.fsf_file = level1design_out.outputs.fsf_files
# level1model.inputs.ev_files = level1design_out.outputs.ev_files
# out=level1model.run()
#
# #filmgls.inputs.in_file = masker_out.outputs.out_file
# #filmgls.inputs.design_file = out.outputs.design_file
# #filmgls.inputs.tcon_file = out.outputs.con_file
# #filmgls.inputs.fcon_file = out.outputs.fcon_file
# #fil_out = filmgls.run()

# %% [raw]
# desmtx=numpy.loadtxt(out.outputs.design_file,skiprows=5)
# plt.imshow(desmtx,aspect='auto',interpolation='nearest',cmap='gray')
# plt.title('Design Matrix')
# plt.show()
# cc=numpy.corrcoef(desmtx.T)
# plt.imshow(cc,aspect='auto',interpolation='nearest', cmap=plt.cm.viridis)
# plt.colorbar()
# plt.title('Correlation of Regressors')
# plt.show()
# # show first regressors
# plt.figure(figsize=[16,6])
# colors = ['m','c']
# for designi, conti in [(0,0),(2,1)]:
#     plt.plot(desmtx[:,designi], c=colors[conti], label=subject_info.conditions[conti])
#     ax = plt.gca()
#     for i in subject_info.onsets[conti]:
#         plt.axvline(i/.68, ymin=0, ymax=.1, c=colors[conti])
# plt.legend()
# plt.title('Incongruent Regressors')

# %% [raw]
# import nilearn.plotting
# import nilearn.image
#
# nilearn.plotting.plot_glass_brain(nilearn.image.smooth_img(fil_out.outputs.zstats[0], 6),
#                                       display_mode='lyrz', colorbar=True, plot_abs=False, threshold=1)
#
# nilearn.plotting.plot_glass_brain(nilearn.image.smooth_img(fil_out.outputs.zstats[1], 6),
#                                       display_mode='lyrz', colorbar=True, plot_abs=False, threshold=1)
#
# nilearn.plotting.plot_glass_brain(nilearn.image.smooth_img(fil_out.outputs.zstats[2], 6),
#                                       display_mode='lyrz', colorbar=True, plot_abs=False, threshold=1)

# %% [markdown]
# # Workflow

# %%
# Initiation of the 1st-level analysis workflow
l1analysis = Workflow(name='l1analysis')
l1analysis.base_dir = join(experiment_dir, working_dir)

# Connect up the 1st-level analysis components
l1analysis.connect([(infosource, selectfiles, [('subject_id', 'subject_id'),
                                               ('task', 'task')]),
                    (infosource, getsubjectinfo, [('subject_id','subject_id'),
                                                 ('task', 'task')]),
                    (selectfiles, masker, [('func','in_file'),
                                           ('mask', 'mask_file')]),
                    (getsubjectinfo, modelspec, [('subject_info','subject_info')]),
                    (masker, modelspec, [('out_file', 'functional_runs')]),
                    (modelspec, level1design, [('session_info','session_info')]),
                    (getsubjectinfo, level1design, [('contrasts','contrasts')]),
                    (level1design, level1model, [('ev_files', 'ev_files'),
                                                 ('fsf_files','fsf_file')]),
                    (masker, filmgls, [('out_file', 'in_file')]),
                    (level1model, filmgls, [('design_file', 'design_file'),
                                            ('con_file', 'tcon_file'),
                                            ('fcon_file', 'fcon_file')]),
                    (level1model, datasink, [('design_file', '1stLevel.@design_file')]),
                    (filmgls, datasink, [('zstats', '1stLevel.@Z'),
                                        ('fstats', '1stLevel.@F'),
                                        ('tstats','1stLevel.@T'),
                                        ('param_estimates','1stLevel.param_estimates')]),
                    (infosource, save_subjectinfo, [('subject_id','subject_id'),
                                                     ('task', 'task')]),
                    (getsubjectinfo, save_subjectinfo, [('subject_info','subject_info'),
                                                        ('contrasts','contrasts')]),
                    
                    ])

# %% [markdown]
# ### Run the Workflow

# %%
l1analysis.run('MultiProc', plugin_args={'n_procs': 4})
# Out:
# 170531-20:55:22,449 workflow INFO:
# 	 Workflow l1analysis settings: ['check', 'execution', 'logging']
# 170531-20:55:22,468 workflow INFO:
# 	 Running in parallel.
# 170531-20:55:22,473 workflow INFO:
# 	 Executing: getsubjectinfo.a0 ID: 0
# 170531-20:55:22,478 workflow INFO:
# 	 Executing: selectfiles.a0 ID: 2
# 170531-20:55:22,482 workflow INFO:
# 	 Executing node getsubjectinfo.a0 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_CCTHot/getsubjectinfo
# 170531-20:55:22,491 workflow INFO:
# 	 Executing node selectfiles.a0 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_CCTHot/selectfiles
# 170531-20:55:22,555 workflow INFO:
# 	 [Job finished] jobname: selectfiles.a0 jobid: 2
# 170531-20:55:22,560 workflow INFO:
# 	 Executing: masker.a0 ID: 3
# 170531-20:55:22,583 workflow INFO:
# 	 Executing node masker.a0 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_CCTHot/masker
# 170531-20:55:22,605 workflow INFO:
# 	 Running: fslmaths /home/jovyan/work/output/Data/sub-s358/ses-1/func/sub-s358_ses-1_task-CCTHot_run-1_bold_space-MNI152NLin2009cAsym_preproc.nii.gz -mas /home/jovyan/work/output/Data/sub-s358/ses-1/func/sub-s358_ses-1_task-CCTHot_run-1_bold_space-MNI152NLin2009cAsym_brainmask.nii.gz /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_CCTHot/masker/sub-s358_ses-1_task-CCTHot_run-1_bold_space-MNI152NLin2009cAsym_preproc_masked.nii.gz
# 170531-20:55:23,346 workflow INFO:
# 	 [Job finished] jobname: getsubjectinfo.a0 jobid: 0
# 170531-20:55:23,350 workflow INFO:
# 	 Executing: savesubjectinfo.a0 ID: 1
# 170531-20:55:24,282 workflow INFO:
# 	 Executing node savesubjectinfo.a0 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_CCTHot/savesubjectinfo
# 170531-20:55:27,205 workflow INFO:
# 	 [Job finished] jobname: savesubjectinfo.a0 jobid: 1
# 170531-20:56:49,697 workflow INFO:
# 	 [Job finished] jobname: masker.a0 jobid: 3
# 170531-20:56:49,701 workflow INFO:
# 	 Executing: modelspec.a0 ID: 4
# 170531-20:56:50,1 workflow INFO:
# 	 Executing node modelspec.a0 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_CCTHot/modelspec
# 170531-20:56:53,617 workflow INFO:
# 	 [Job finished] jobname: modelspec.a0 jobid: 4
# 170531-20:56:53,620 workflow INFO:
# 	 Executing: level1design.a0 ID: 5
# 170531-20:56:54,796 workflow INFO:
# 	 Executing node level1design.a0 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_CCTHot/level1design
# 170531-20:56:57,702 workflow INFO:
# 	 [Job finished] jobname: level1design.a0 jobid: 5
# 170531-20:56:57,706 workflow INFO:
# 	 Executing: FEATModel.a0 ID: 6
# 170531-20:56:58,143 workflow INFO:
# 	 Executing node FEATModel.a0 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_CCTHot/FEATModel
# 170531-20:56:58,164 workflow INFO:
# 	 Running: feat_model run0
# 170531-20:57:02,177 workflow INFO:
# 	 [Job finished] jobname: FEATModel.a0 jobid: 6
# 170531-20:57:02,181 workflow INFO:
# 	 Executing: FILMGLS.a0 ID: 7
# 170531-20:57:02,207 workflow INFO:
# 	 Executing node FILMGLS.a0 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_CCTHot/FILMGLS
# 170531-20:57:02,217 workflow INFO:
# 	 Running: film_gls --rn=results --con=/home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_CCTHot/FEATModel/run0.con --in=/home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_CCTHot/masker/sub-s358_ses-1_task-CCTHot_run-1_bold_space-MNI152NLin2009cAsym_preproc_masked.nii.gz --pd=/home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_CCTHot/FEATModel/run0.mat --thr=0.000000
# 170601-00:42:48,542 workflow INFO:
# 	 [Job finished] jobname: FILMGLS.a0 jobid: 7
# 170601-00:42:48,557 workflow INFO:
# 	 Executing: datasink.a0 ID: 8
# 170601-00:42:48,644 workflow INFO:
# 	 Executing node datasink.a0 in dir: /home/jovyan/work/output/workingdir/l1analysis/_subject_id_sub-s358_task_CCTHot/datasink
# 170601-00:42:48,689 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_CCTHot/tstat1.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_CCTHot/tstat1.nii.gz
# 170601-00:42:48,693 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_CCTHot/tstat2.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_CCTHot/tstat2.nii.gz
# 170601-00:42:48,695 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_CCTHot/zstat1.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_CCTHot/zstat1.nii.gz
# 170601-00:42:48,696 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_CCTHot/zstat2.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_CCTHot/zstat2.nii.gz
# 170601-00:42:48,698 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/_subject_id_sub-s358_task_CCTHot/run0.mat -> /home/jovyan/work/output/datasink/1stLevel/sub-s358_task_CCTHot/designfile.mat
# 170601-00:42:48,703 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe1.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe1.nii.gz
# 170601-00:42:48,708 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe2.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe2.nii.gz
# 170601-00:42:48,710 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe3.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe3.nii.gz
# 170601-00:42:48,713 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe4.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe4.nii.gz
# 170601-00:42:48,715 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe5.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe5.nii.gz
# 170601-00:42:48,718 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe6.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe6.nii.gz
# 170601-00:42:48,720 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe7.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe7.nii.gz
# 170601-00:42:48,722 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe8.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe8.nii.gz
# 170601-00:42:48,725 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe9.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe9.nii.gz
# 170601-00:42:48,727 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe10.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe10.nii.gz
# 170601-00:42:48,731 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe11.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe11.nii.gz
# 170601-00:42:48,743 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe12.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe12.nii.gz
# 170601-00:42:48,745 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe13.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe13.nii.gz
# 170601-00:42:48,748 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe14.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe14.nii.gz
# 170601-00:42:48,758 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe15.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe15.nii.gz
# 170601-00:42:48,766 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe16.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe16.nii.gz
# 170601-00:42:48,770 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe17.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe17.nii.gz
# 170601-00:42:48,774 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe18.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe18.nii.gz
# 170601-00:42:48,779 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe19.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe19.nii.gz
# 170601-00:42:48,786 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe20.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe20.nii.gz
# 170601-00:42:48,792 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe21.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe21.nii.gz
# 170601-00:42:48,799 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe22.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe22.nii.gz
# 170601-00:42:48,805 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe23.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe23.nii.gz
# 170601-00:42:48,811 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe24.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe24.nii.gz
# 170601-00:42:48,827 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe25.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe25.nii.gz
# 170601-00:42:48,832 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe26.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe26.nii.gz
# 170601-00:42:48,837 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe27.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe27.nii.gz
# 170601-00:42:48,841 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe28.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe28.nii.gz
# 170601-00:42:48,847 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe29.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe29.nii.gz
# 170601-00:42:48,852 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe30.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe30.nii.gz
# 170601-00:42:48,864 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe31.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe31.nii.gz
# 170601-00:42:48,873 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe32.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe32.nii.gz
# 170601-00:42:48,881 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe33.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe33.nii.gz
# 170601-00:42:48,885 interface INFO:
# 	 sub: /home/jovyan/work/output/datasink/1stLevel/param_estimates/_subject_id_sub-s358_task_CCTHot/pe34.nii.gz -> /home/jovyan/work/output/datasink/1stLevel/param_estimates/sub-s358_task_CCTHot/pe34.nii.gz
# 170601-00:42:48,916 workflow INFO:
# 	 [Job finished] jobname: datasink.a0 jobid: 8

# %% [markdown]
# ### Visualize Workflow

# %%
# Create 1st-level analysis output graph
l1analysis.write_graph(graph2use='colored', format='png', simple_form=True)
# Visualize the graph
from IPython.display import Image
graph_file=join(l1analysis.base_dir, 'l1analysis', 'graph.dot.png')
Image(graph_file)
# Out:
# 170601-00:42:50,215 workflow INFO:
# 	 Converting dotfile: /home/jovyan/work/output/workingdir/l1analysis/graph.dot to png format

# %%
try:
    shutil.move(graph_file, 'l1analysis')
except shutil.Error:
    pass
# remove working directory
shutil.rmtree(working_dir)

# %% [markdown]
# ### Visualize Design Matrix

# %%
# !tree datasink/1stLevel/sub*
# Out:
# datasink/1stLevel/sub-s358_task_ANT
# ├── designfile.mat
# ├── pe10.nii.gz
# ├── pe11.nii.gz
# ├── pe12.nii.gz
# ├── pe13.nii.gz
# ├── pe14.nii.gz
# ├── pe15.nii.gz
# ├── pe16.nii.gz
# ├── pe17.nii.gz
# ├── pe18.nii.gz
# ├── pe19.nii.gz
# ├── pe1.nii.gz
# ├── pe20.nii.gz
# ├── pe21.nii.gz
# ├── pe22.nii.gz
# ├── pe23.nii.gz
# ├── pe24.nii.gz
# ├── pe25.nii.gz
# ├── pe26.nii.gz
# ├── pe27.nii.gz
# ├── pe28.nii.gz
# ├── pe29.nii.gz
# ├── pe2.nii.gz
# ├── pe30.nii.gz
# ├── pe31.nii.gz
# ├── pe3.nii.gz
# ├── pe4.nii.gz
# ├── pe5.nii.gz
# ├── pe6.nii.gz
# ├── pe7.nii.gz
# ├── pe8.nii.gz
# ├── pe9.nii.gz
# ├── subjectinfo.pkl
# ├── tstat1.nii.gz
# ├── tstat2.nii.gz
# ├── tstat3.nii.gz
# ├── tstat4.nii.gz
# ├── tstat5.nii.gz
# ├── tstat6.nii.gz
# ├── zstat1.nii.gz
# ├── zstat2.nii.gz
# ├── zstat3.nii.gz
# ├── zstat4.nii.gz
# ├── zstat5.nii.gz
# └── zstat6.nii.gz
# datasink/1stLevel/sub-s358_task_CCTHot
# ├── contrasts.pkl
# ├── designfile.mat
# ├── subjectinfo.pkl
# ├── tstat1.nii.gz
# ├── tstat2.nii.gz
# ├── zstat1.nii.gz
# └── zstat2.nii.gz
# datasink/1stLevel/sub-s358_task_stroop
# ├── designfile.mat
# ├── pe10.nii.gz
# ├── pe11.nii.gz
# ├── pe12.nii.gz
# ├── pe13.nii.gz
# ├── pe14.nii.gz
# ├── pe15.nii.gz
# ├── pe16.nii.gz
# ├── pe17.nii.gz
# ├── pe18.nii.gz
# ├── pe19.nii.gz
# ├── pe1.nii.gz
# ├── pe20.nii.gz
# ├── pe21.nii.gz
# ├── pe22.nii.gz
# ├── pe23.nii.gz
# ├── pe24.nii.gz
# ├── pe25.nii.gz
# ├── pe26.nii.gz
# ├── pe27.nii.gz
# ├── pe28.nii.gz
# ├── pe29.nii.gz
# ├── pe2.nii.gz
# ├── pe3.nii.gz
# ├── pe4.nii.gz
# ├── pe5.nii.gz
# ├── pe6.nii.gz
# ├── pe7.nii.gz
# ├── pe8.nii.gz
# ├── pe9.nii.gz
# ├── subjectinfo.pkl
# ├── tstat1.nii.gz
# ├── tstat2.nii.gz
# ├── tstat3.nii.gz
# ├── zstat1.nii.gz
# ├── zstat2.nii.gz
# └── zstat3.nii.gz
#
# 0 directories, 89 files

# %%
design_file = glob(join(experiment_dir,'datasink','1stLevel','sub-s358_task_CCTHot','designfile.mat'))[0]
desmtx=numpy.loadtxt(design_file, skiprows=5)
plt.imshow(desmtx,aspect='auto',interpolation='nearest',cmap='gray')
plt.title('Design Matrix')
plt.show()
cc=numpy.corrcoef(desmtx.T)
plt.imshow(cc,aspect='auto',interpolation='nearest', cmap=plt.cm.viridis)
plt.colorbar()
plt.title('Correlation of Regressors')
plt.show()
"""
# show first regressors
plt.figure(figsize=[20,8])
plt.plot(desmtx[:,0],'b', label=subject_info.conditions[0])
plt.plot(desmtx[:,2],'r', label=subject_info.conditions[1])
for i in subject_info.onsets[0]:
    plt.axvline(i/.68, ymin=0, ymax=.1)
for i in subject_info.onsets[1]:
    plt.axvline(i/.68, ymin=0, ymax=.1, c='r')
plt.legend()
plt.title('Congruent/Incongruent Regressors')
"""
# Out:
# "\n# show first regressors\nplt.figure(figsize=[20,8])\nplt.plot(desmtx[:,0],'b', label=subject_info.conditions[0])\nplt.plot(desmtx[:,2],'r', label=subject_info.conditions[1])\nfor i in subject_info.onsets[0]:\n    plt.axvline(i/.68, ymin=0, ymax=.1)\nfor i in subject_info.onsets[1]:\n    plt.axvline(i/.68, ymin=0, ymax=.1, c='r')\nplt.legend()\nplt.title('Congruent/Incongruent Regressors')\n"

# %% [markdown]
# ### Visualize Results

# %%
from nilearn.plotting import plot_stat_map
from nilearn.image import smooth_img

anatimg = glob(join(experiment_dir,'Data','sub-s358','anat','*T1w*MNI*preproc*'))[0]
contrast_img = glob(join(experiment_dir,'datasink','1stLevel','sub-s358_task_ANT','zstat3.nii.gz'))[0]
plot_stat_map(smooth_img(contrast_img, 8), title='stroop effect',
              bg_img=anatimg, threshold=1, display_mode='z', cut_coords=(-30, -15, 0, 15, 30), dim=-1)
# Out:
# /opt/conda/envs/python2/lib/python2.7/site-packages/matplotlib/__init__.py:1401: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)
# /opt/conda/envs/python2/lib/python2.7/site-packages/nilearn/plotting/displays.py:649: UserWarning: empty mask
#   get_mask_bounds(new_img_like(img, not_mask, affine))
# /opt/conda/envs/python2/lib/python2.7/site-packages/matplotlib/artist.py:879: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.
#   return func(v)

# %%
import nilearn.plotting
import nilearn.image
import cPickle

for task in task_list:
    contrast_file = glob(join(experiment_dir,'datasink','1stLevel','sub-s358_task_' + task,'contrasts.pkl'))[0]
    contrasts = cPickle.load(open(contrast_file,'r'))
    contrasts = [contrast[0] for contrast in contrasts]
    contrast_imgs = sort(glob(join(experiment_dir,'datasink','1stLevel','sub-s358_task_' + task,'zstat*.nii.gz')))
    for i, contrast_img in enumerate(contrast_imgs):
        nilearn.plotting.plot_glass_brain(nilearn.image.smooth_img(contrast_img, 8),
                                          display_mode='lyrz', colorbar=True, plot_abs=False, threshold=0,
                                          title=contrasts[i])
